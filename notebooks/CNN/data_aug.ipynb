# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
img = image.load_img("/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/notebooks/CNN/datasets/train_aug/cat.3.jpg", target_size=(256,256))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
datagen = ImageDataGenerator(
    rotation_range = 30,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True   
    
)

# %%
img = image.img_to_array(img)

# %%
input_batch = img.reshape(1,256,256,3)

# %%
i=0
for output in datagen.flow(input_batch, batch_size=1, save_to_dir='/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/notebooks/CNN/datasets/train_aug'):
    i = i+1
    if i==10:
        break
