# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def softmax(x):
    e_x = np.exp(x-np.max(x))
    softmax_val = e_x / e_x.sum(axis = 0)
    percent_val = softmax_val * 100
    formatted_percent_values = [f"{value}"]
