# %%
# importing the dependecies

import pandas as pd
import numpy as np
import gensim
import os
from gensim.utils import simple_preprocess
from nltk.tokenize import sent_tokenize

# %%
docs = []
for file in os.listdir('datasets'):
    with open(os.path.join('datasets', file), encoding='latin-1') as f:
        corpus = f.read()
        
    raw_sent = sent_tokenize(corpus)
    
    for t in raw_sent:
        docs.append(simple_preprocess(t))

# %%
os.listdir('datasets')
# Out:
# ['1 - A Game of Thrones.txt',
#  '2 - A Clash of Kings.txt',
#  '3 - A Storm of Swords.txt',
#  '4 - A Feast for Crows.txt',
#  '5 - A Dance with Dragons.txt']

# %%
len(docs)
# Out:
# 145020

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
    
)

# %%
model.build_vocab(docs)

# %%
model.train(docs, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6569449, 8628190)
