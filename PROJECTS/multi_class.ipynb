# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten
from keras import Sequential
import zipfile
import os
# Out:
# 2026-01-13 12:35:18.554850: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# with zipfile.ZipFile("/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/PROJECTS/vegetables.zip", 'r') as zipped_folder:
#     zipped_folder.extractall("/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/PROJECTS")

# %%
gpus = tf.config.list_physical_devices("GPU")
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# %%
test_data = keras.utils.image_dataset_from_directory(
    "/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/PROJECTS/multi_class/test",
    image_size = (128,128),
    label_mode = 'int',
    batch_size = 16,
    shuffle = True,
)
# Out:
# Found 359 files belonging to 36 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768307723.013578   10255 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1766 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
os.listdir("/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/PROJECTS/multi_class/test")
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
train_data = keras.utils.image_dataset_from_directory(
    "/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/PROJECTS/multi_class/train",
    batch_size = 16,
    image_size = (128, 128),
    shuffle = True,
    label_mode = 'int'
)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
validation_data = keras.utils.image_dataset_from_directory(
    "/mnt/c/Users/Subham Pathak/Desktop/AI/DEEP_LEARNING/PROJECTS/multi_class/validation",
    batch_size = 16,
    image_size = (128, 128),
    shuffle = True,
    label_mode = 'int'
)
# Out:
# Found 351 files belonging to 36 classes.

# %%
def process(image, label):
    tf.cast(image/128, dtype=tf.float32)
    return image, label

# %%
train_data = train_data.map(process)
test_data = test_data.map(process)
validation_data = validation_data.map(process)

# %%
# lets build model
model = Sequential()

model.add(Input(shape=(128,128,3)))

model.add(Conv2D(32, kernel_size=(2,2), strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2))
model.add(BatchNormalization())

model.add(Conv2D(16, kernel_size=(2,2), strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2))
model.add(BatchNormalization())

model.add(Conv2D(32, kernel_size=(2,2), strides=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=2))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(64, activation='relu' ))
model.add(Dropout(0.1))

model.add(Dense(16, activation='relu' ))
model.add(Dropout(0.1))

model.add(Dense(1, activation='softmax' ))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 32)     │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 16)     │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(train_data, batch_size=16, epochs=20, validation_data=validation_data)
